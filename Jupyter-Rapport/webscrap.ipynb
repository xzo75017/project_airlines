# %%
from operator import itemgetter
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import json


    

def get_data(compteur, ville):
    
    '''
    Fonction permettant de webscrapper les evenements d'une ville sur le site allevents.in
    Paramètre :
    -compteur : compteur permettant de parcourir les pages jusqu'à scrapper le dernier évenement disponible
    
    Sortie :
    dataFrame contenant les informations pour la page parcourue
    '''
    
    page = urlopen("https://allevents.in/" + ville + "/all?page="+str(compteur))
    soup = BeautifulSoup(page, 'html.parser')
    ##recupere les titres de la page avec l'outil selectorGadget
    title = soup.select(".title h3")
    # Récupérer les titres propres, on utilise l'attribut text et la boucle
    # Renseigne ensuite ce chemin CSS dans la méthode select
    mois = soup.findAll(name = 'span', attrs = {'class':'up-month'})
    jour = soup.findAll(name = 'span', attrs = {'class':'up-day'})
    # Récupérer les titres des activités propres, on utilise l'attribut text et la boucle
    noms_activite = []
    mois_activite = []
    jour_activite = []
    for nom_it, mois_it, jour_it in zip(title, mois, jour) :
        noms_activite.append(nom_it.text)
        mois_activite.append(mois_it.text.strip("()"))
        jour_activite.append(jour_it.text.strip("()")[:2])
        
    result = pd.DataFrame(list(zip(noms_activite,mois_activite,jour_activite)), columns=["Titre","Mois","Jour"])
    
    return result



def scrap(ville):
    '''
    Recupère le webscrapping et le renvoie sous forme de dictionnaire
    '''
    i=1
    table_activity = pd.DataFrame(columns=["Titre","Mois","Jour", "Ville"])
    while True:
        result = get_data(i, ville)
        if len(result) > 1:
            table_activity = pd.concat([table_activity, result])
            i+=1
        else :
            break
    table_activity['Ville'] = ville    
    dict = table_activity.to_dict(orient='list')
    return dict

# %%
scrap('London')
# Out:
# {'Titre': ['AM After Hours ',
#   'Voltstorm Live in London',
#   'Rejoin March Saturday 22 October 2022  Coach Tickets',
#   'Hiking the Jurassic Coast UNESCO World Heritage Coastline',
#   'The Trip to London Madame Tussauds Museum ',
#   'London To Brighton Cycle Ride via Devils Dyke',
#   'London To Brighton Cycle Ride via Devils Dyke',
#   'Acting for Film, Camera and Sound workshop',
#   'The Smart Works Fashion Sale ',
#   'Merlin’s Magical London: 3 Attractions In 1 – Madame Tussauds + The Lastminute.com London Eye + Sea Life',
#   "Merlin’s Magical London - Madame Tussauds + The Lastminute.com London Eye + Shrek's Adventure",
#   'Madame Tussauds London - Standard Entry',
#   'Madame Tussauds London - Standard Admission + Marvel 4d',
#   'Merlin’s Magical London - Madame Tussauds + The Lastminute.com London Eye + The London Dungeon',
#   'The RNLI Tower Run',
#   '',
#   '10th Annual Conference',
#   'TCS London Marathon 2022',
#   'Bionabu Health Entrepreneurship and Innovation Summit',
#   'Accredited Feng Shui Foundation Course',
#   'Messiah Come & Sing Tour: LONDON',
#   'Athena In-Person Hackathon - All Women and Non-Binary Tech Event',
#   'Rent to Serviced Accommodation Summit LONDON',
#   'Rent To Serviced Accommodation  Summit | LONDON',
#   'UK Black Business Show 2022',
#   'Big Walk London jubilee walkway',
#   "Brixton Startup Weekend and Lyan's Den finale",
#   "Tuff Nutterz, HALF TERM FUN - UK's biggest bouncy obstacle course, Guilford",
#   'Big Walk! London edition',
#   'Sea Life London - Standard Entry',
#   "Merlin’s Magical London - Sea Life + Shrek's Adventure + London Dungeon + The Lastminute.com London Eye + Madame Tussauds",
#   '',
#   'Merlin’s Magical London - Sea Life + Shrek’s Adventure! + The Lastminute.com London Eye',
#   'Merlin’s Magical London: 3 Attractions In 1 – Sea Life + Madame Tussauds + The Lastminute.com London Eye',
#   'Merlin’s Magical London: 3 Attractions In 1 – Sea Life + Shrek’s Adventure! + Madame Tussauds',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Madame Tussauds',
#   'The View From The Shard',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Sea Life',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure + The Lastminute.com London Eye + Sea Life",
#   'Merlin’s Magical London: 5 Attractions In 1 –  London Dungeon + The Lastminute.com London Eye + Shrek’s Adventure + Sea Life + Madame Tussauds',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + The Lastminute.com London Eye + Madame Tussauds",
#   'Merlin’s Magical London: 3 Attractions In 1 -  The London Dungeon + Sea Life + Madame Tussauds',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + Sea Life + Madame Tussauds",
#   'Shrek’s Adventure! London – Daily Entry',
#   'Executions',
#   'Monopoly Lifesized - Classic Board',
#   'State of the Browser 2022 Web Conference',
#   '',
#   'Stick Man',
#   'Mindful Sound Flow - Open Class (Saturdays 9.30am)',
#   'Prophecy for Everyone - The School of Radical Discipleship',
#   'Fitness for over Forties',
#   'Monopoly Lifesized - City Board',
#   'The Smart Works Fashion Sale',
#   'Medhelp',
#   'Polio Vaccination Event - 09:30 - 16:30 The Grey Coat Hospital School',
#   'Urban hike - Waterloo to Greenwich',
#   'Money Tree . Accessing Abundance and Wealth using Family Constellations',
#   'Monopoly Lifesized - Luxury Board',
#   'The Lastminute.com London Eye River Cruise',
#   'Rewriting Wellbeing: The Health & Wellbeing Event for Educators',
#   'EXCELLING IN EDUCATION - THE ANNUAL CONFERENCE',
#   'Weekend Clown Workshop in London with Jon Davison',
#   '',
#   'Nobody But GOD',
#   'Shroomshop Pro: Two Day Advanced Mushroom Cultivation with Darren Le Baron',
#   'Southwark Archdiocese Day of Renewal 2022',
#   'Takimet e mëngjesit për Kafe @ PH',
#   'Paint Hampstead Landscape, NW3, Heath overlooking London',
#   'DAMAC COMES TO LONDON! Dubai Investment Property Show',
#   'Zumba Fitness Lesson',
#   "People's Pavilion Design Competition - Hackney (Age 14-18)",
#   'Money Tree . Accessing Abundance and Wealth using Family Constellations',
#   'Ebi Fusions Plant Based Artisian Market',
#   'PUMPKIN TIME at The GROW Farm!',
#   'Knitters Anonymous @ Yurt',
#   'Lakeside Centre Kids Art Club',
#   'Senza Circuits Boot Kamp',
#   'Beginner +  Ride Walpole Park to Osterley House',
#   '',
#   'Hidden Gems of Lambeth Walking Tour:  Lambeth North to Lambeth Palace',
#   'Top Trumps trail at London Zoo',
#   'Adopted people in-person meet-up - London Family Action Head Office',
#   'Dubai Luxury Property Symposium Manchester',
#   'Opening of LAKRIDS BY BÜLOW pop-up at Selfridges London ',
#   "Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye+ Madame Tussauds + Shrek's Adventure",
#   'Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye + Madame Tussauds + Sealife London',
#   'WATCCH Interview and Coaching Skills Workshop',
#   'PILATES IN THE PARK',
#   'Houseplant Festival 2022',
#   "MOTHER's DIWALI Celebration and Art Fair",
#   'Jeff Wayne’s The War Of The Worlds: The Immersive Experience',
#   'Trek/Fit Scenic Hikes: Halloween Special, Pluckley Village',
#   'Stick Man - Live On Stage',
#   "GABBY KING {SHAHEEN BAIG CASTING} - 'IN PERSON' TV / FILM WORKSHOP!",
#   '',
#   'MATT SHEPPARD FREELANCE CASTING ASSOCIATE | IN-PERSON TV / FILM WORKSHOP',
#   'London loop',
#   'Essential communication skills',
#   'How does your mind work?',
#   'How to boost self-confidence',
#   'Conquering everyday fears',
#   'Destress Refresh Yoga',
#   'Discover Your Wilderhood Wildlife Walk - New Cross',
#   'Polygon x EasyA Hackathon [22-23 Oct]',
#   'Yoga at New Road Hotel',
#   'Caravan Coffee School: Roastery Tour and Tasting Class',
#   'The London Welsh  Autumn Emporium ',
#   'Authentic Japanese Reiki Training @ Reiki Maya London Centre',
#   'Self Compassion Workshop',
#   'The Lastminute.com London Eye - Standard Entry',
#   '',
#   'Parallax Art Fair October 2022  (Saturday)',
#   'The Reggae Brunch - Sat 22nd October',
#   'The Reggae Brunch - Sat 22nd October',
#   'Beyond the Rebel Nazrul Islam',
#   "DEAD MAN'S PLACE - 2,000 Years of Death in London A Guided Tour around Bankside and Old Southwark",
#   'Discovering the hidden gems of Hatton Garden',
#   'BCS/NCA BookClub at a Posh Bar',
#   'Join us for the ultimate 90s Throwback Brunch',
#   'Its Black history month, hosted by Unity link up',
#   'Live London Property Q & A Masterclass (Bring all your property questions)',
#   'A South London Makers Fashion Market in Crystal Palace',
#   'Ballet Class 4yrs-10yrs',
#   'Diwali Celebration Craft @Hale End Library',
#   'Kosmonauts Isle of Dogs walk',
#   'Aga Khan Centre Weekly Tours',
#   '',
#   'One Team Scavenger London England',
#   'Artists’ Talk with Tanabe Chikuunsai IV & Sawako Kaijima and Kensuke Koike',
#   'Masterclass: Vegan West African Twists - Black History Month Special',
#   'Sexual Trauma Survivors Group',
#   'Halloween Special Brixton Vintage K*ll-o Sale!',
#   'Harry Styles Themed PYOP | CARB CLUB',
#   'DRAG BOTTOMLESS BRUCH',
#   'Orchard Day',
#   'The Key to our Soul',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   'ISL - Improv as a Second Language // October Drop-In',
#   'One hour workshop, hand built dish suitable for a tea light',
#   'Intro to Thai Style Massage',
#   'Introduction to The Line - Free Guided Tours',
#   'Afro Pump',
#   '',
#   'Spoken Word Talk & Performance by Asante',
#   'UNIQLO Tate Play - Autumn Art Workshop',
#   'WE Sustain 2022 - Day 2 -Waste not, Want not.',
#   'POPUP UNITED RELAUNCH PARTY',
#   'KAP Kundalini Activation Process - Wimbledon',
#   'ABBA Bottomless Brunch Comes To London! [18+]',
#   'Celebrating black history and craft fair',
#   'Afro Bloc Drumming (Samba)',
#   'Taste of Philippines Cooking Class - Sourness',
#   'Chelsea FC Fans Pre Match Boat Party',
#   'Bike Basics for Families',
#   'Shoreditch HipHop & RnB Brunch Party',
#   'PONY - Old Skool RnB Brunch',
#   'A Day At My House - The Trilogy',
#   "THE GOOD TIMES BRUNCH - Shoreditch's Ultimate Brunch Party",
#   '',
#   'Family Jam Early Session',
#   'On the dark side. Halloween edition',
#   'Letting The Mind Breathe',
#   '#4Years1Dream with ATEEZ - 4th Anniversary Cupsleeve Event',
#   'Seniors and Friends Afternoon Tea and Dance',
#   'Asiana Wedding Weekend - 22nd & 23rd October 2022',
#   "'People of Wardley Street' Guided Walk and Plaque Unveiling",
#   "Free Lunchtime Tour of St.Mary Magdalene's Neo-Gothic Church, Paddington",
#   'Bottomless Day Party Brunch',
#   'Oxfam meet-up London',
#   'Blowdries and  Bentos',
#   "Back to the 90s with Shyanne O'Shea",
#   'all-dayer w/ tony goff and the broken colours',
#   'Camden Rocks All-dayer W/ Urock And More',
#   'Freaky Fashion Show',
#   '',
#   'Saturday Free Flowing Brunch at The Maine Mayfair',
#   'Queen Model Academy',
#   '20th Anniversary Wine Festival',
#   'Latin Jazz Brunch Live with Brotherhood Of Breath (Live) ',
#   'QUEER AUTUMN FORAGE',
#   '50 Ways to Die (in 1632): A Creative Filmmaking Workshop',
#   '2022 LTBS Welcome Mingle 倫敦台灣生醫學會迎新',
#   'Peckham Soup Kitchen Launch Event',
#   'CRE8TORS HALLOWEEN EVENT',
#   'Bottomless Brunch Party at The Maine Mayfair',
#   'SANPELLEGRINO PIAZZA BAR',
#   'Latin Jazz Brunch Live with Brotherhood Of Breath x Sarabanda',
#   'Black Curatorial Lab: IRL TINGS',
#   'Parent and Toddler Performing Arts',
#   'SDRD Saturday Training',
#   '',
#   'SANPELLEGRINO PIAZZA BAR',
#   'Latin Jazz Brunch Live with Brotherhood Of Breath x Sarabanda',
#   'Black Curatorial Lab: IRL TINGS',
#   'Parent and Toddler Performing Arts',
#   'SDRD Saturday Training',
#   'The Reggae Brunch - SAT 22ND OCT',
#   'Freedom Formation: Leicester Square - 22nd October 2022',
#   'Stick Man - Live On Stage',
#   'Workshop. Clowning and Physical Comedy with Dave Thompson',
#   'DWTN Paint and Brunch: Ms Hill',
#   'Workshop. Clowning and Physical Comedy with Dave Thompson',
#   'EL BANDARRA APERITIVO HOUR WITH THE CASTELLERS OF LONDON',
#   'The Gunpowder Plot',
#   'Hidden Gems of Lambeth Walking Tour: from Lambeth Palace to Vauxhall',
#   '@2:50 - ten minutes of daily mindfulness EEST  (in BST)',
#   '',
#   'I, Joan',
#   'My Neighbour Totoro',
#   'OKTOBERFEST SOUTH LONDON',
#   'Inferno',
#   'Move Smooth',
#   'Harry Potter And The Cursed Child',
#   'Frozen The Musical',
#   'The Lion, The Witch And The Wardrobe',
#   'Activate Your Creativity',
#   "Sip 'N Stroke |1pm - 4pm| 90's Dress Up | Sip and Paint Party",
#   'To K*ll A Mockingbird',
#   'Camden Rocks All-Dayer w/ Alexis Kings & more at Camden Assembly - London',
#   'Camden Oktoberfest',
#   'Ancestors calling day retreat',
#   'New Wave Lunchtime Concert: Lucilla Rose Mariotti',
#   '',
#   'HelloFresh Halloween Cookalong at SITU LIVE',
#   'Road To Hyrox - Blackwall Training Weekend',
#   'National Day of Protest - Imperial College, London',
#   'My Neighbour Totoro',
#   'Super Saturday - 22nd October',
#   'Tripwire 30th Anniversary Signing',
#   'ForestFest',
#   'Contemporary Female Directors from Turkey: 4 Films, Being a Woman in Turkey',
#   'All-Dayer w/ UROCK and more',
#   'Anticucho Peruvian Day!',
#   "G's Health & Fitness Workout",
#   'The Doctor',
#   'Good',
#   'The Drifters Girl',
#   'Get Up, Stand Up! The Bob Marley Musical',
#   '',
#   'Anticucho Peruvian Day!',
#   "G's Health & Fitness Workout",
#   'The Doctor',
#   'Good',
#   'The Drifters Girl',
#   'Get Up, Stand Up! The Bob Marley Musical',
#   "Disney's The Lion King",
#   'The Play That Goes Wrong',
#   'Life Of Pi',
#   'Wicked',
#   'Back To The Future - The Musical',
#   'Dear Evan Hansen',
#   'Jersey Boys',
#   'The Phantom Of The Opera',
#   'Pretty Woman The Musical',
#   '',
#   'Spoken Word Poetry Open Mic',
#   'Witness For The Prosecution',
#   'Essential communication skills',
#   'How to boost self-confidence',
#   'How does your mind work?',
#   'llusions The Drag Queen Show London - Drag Queen Show - London, UK',
#   'Conquering everyday fears',
#   'Free Forex and Crypto  Introduction For Dummies in London',
#   'Harry Potter and the Cursed Child - Parts 1 & 2 Sat 14:00 & 19:00',
#   'Subterranean Manifestation II',
#   'The Great Gatsby',
#   'CAMDEN OKTOBERFEST 2022',
#   'Peaky Blinders - The Rise',
#   'Stick Man - Live On Stage',
#   'The Mousetrap',
#   '',
#   'Heathers The Musical',
#   'Spooky Fancy Fun House',
#   'NLA Walking Tour – The City',
#   'Somali Week Festival: Children’s Entertainment',
#   'Peaky Blinders: The Rise',
#   'DERIC CHNG ART DINING AND ART SHOW EXPERIENCE 2022',
#   'PEOPLE SKILLS: In-Person',
#   'Plant Care 101 with Patch',
#   'Food lovers required for focus group free tasting',
#   'Time Freedom, Personal Freedom, FINANCIAL Freedom - Canada',
#   '#TimeForChange: Kunda Kids Confidence Workshops',
#   'African Evolution @ The Natural History Museum - BHM 2022',
#   'Sensual Empowerment Sister Circle',
#   'Peaky Blinders: The Rise',
#   'The Great Gatsby',
#   '',
#   'Introducing Unbound Firsts',
#   'LONDON CAMERA CLUB MEET UP - POLE DANCING PHOTOGRAPHY',
#   'King Hamlin',
#   'Peaky Blinders: The Redemption of Thomas Shelby',
#   'The Choir Of Man',
#   'Live Wrestling in Chelsea, afternoon show! ',
#   'Baji Zhandao Kung-Fu/Meditation - OUTDOORS class (Adults 16+)',
#   'Saturday Bottomless Brunch Comedy',
#   'A New Found Mind',
#   'ABBA Voyage',
#   'The Great Gatsby - Immersive',
#   'The Mousetrap',
#   'Six The Musical (vaudeville Theatre)',
#   'Cheese & Wine Tasting',
#   'Family Jam Late Session',
#   '',
#   'New Joiners Day - Ishigaki Jujitsu',
#   'Black History Month Event',
#   'Pole Hire',
#   'Gathering Leaves Hong Kong Library Visit',
#   'Overcome Your Fear of Public Speaking - UK-(Virtual) Free Trial Class',
#   'Melomaniac',
#   'One Dark Knight Signing With Jock',
#   'Salsa for Beginners with Funky Mambo',
#   '10.22 倫敦酒吧 Happy Hour',
#   'Essential communication skills',
#   'How does your mind work?',
#   'How to boost self-confidence',
#   'Conquering everyday fears',
#   'HOW YOU COULD INCREASE YOUR SELF-CONFIDENCE',
#   'Nikolas Schreck - The Manson File UK Book Launch',
#   '',
#   'Pole Hire',
#   'Bottomless Drag Bingo',
#   'HOW YOU COULD INCREASE YOUR SELF-CONFIDENCE',
#   'Awakening Yoga • Weekly Class • London',
#   'Plant Care 101 with Patch',
#   'Social Basketball - Saturday',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   'JOKAklubi: The London Theory Show',
#   'Bond Street Fur and Exotic Skin Trade Protest',
#   'Moist The Oldskool Era',
#   "Sip 'N Stroke | 5pm - 8pm| 90's Dress Up | Sip and Paint Party",
#   'FHP Presents - The Moustache Bar',
#   'Liberated By Love',
#   'Love Is The Answer: A Stress Free Disco Dance',
#   "Tee's  Saturday games night",
#   '',
#   'Bond Street Fur and Exotic Skin Trade Protest',
#   'Moist The Oldskool Era',
#   "Sip 'N Stroke | 5pm - 8pm| 90's Dress Up | Sip and Paint Party",
#   'FHP Presents - The Moustache Bar',
#   'Liberated By Love',
#   'Love Is The Answer: A Stress Free Disco Dance',
#   "Tee's  Saturday games night",
#   'Circus Berlin - Ealing Common',
#   'Tom Chaplin Pre-Concert Meetup |  The Slug and Lettuce London',
#   'Passing Through London',
#   'Passing Through London',
#   'Spanish/English Language Exchange',
#   'WhistlePig Rye Whiskey Tasting & Masterclass',
#   'Try us out for free',
#   "The Frustrated Women's Club - London",
#   '',
#   "Disco Sanctuary 'Warm Up' sessions",
#   "Disco Sanctuary Discovery 'Warm Up' with Maii Morris +",
#   'ACTORS',
#   'CHANGE  OF VENUE   o2  Academy 2 - ACTORS + Auger  + Magnetic  Skies & Vanilla Sugar',
#   'PAVEMENT, Live in London',
#   'Queen Boat Party with FREE PopWorld After Party!',
#   'DJ Nights: Saxon Sound',
#   'MOIST THE OLDSKOOL ERA PART 2 ',
#   '3 x World Bachata Champions Workshop & Pary',
#   'Live Wrestling in Chelsea, evening show!',
#   'Sutton House, London EXCLUSIVE Ghost Hunt - £39',
#   'The Brixton Immortals Domino Club Celebration',
#   'Bachata World Champions in London',
#   'Book Launches and conversations with Huda Ali Banfaz and Cumar Serbia',
#   'BEST OF: Пощенска кутия за приказки в Лондон / 22.10',
#   '',
#   '3 x World Bachata Champions Workshop & Pary',
#   'Live Wrestling in Chelsea, evening show!',
#   'Sutton House, London EXCLUSIVE Ghost Hunt - £39',
#   'The Brixton Immortals Domino Club Celebration',
#   'Bachata World Champions in London',
#   'Book Launches and conversations with Huda Ali Banfaz and Cumar Serbia',
#   'BEST OF: Пощенска кутия за приказки в Лондон / 22.10',
#   'DragRace down under season 2  screenings with host Jess Queen',
#   'Bachata World Champions in London',
#   'Gentle Beginner  Yoga',
#   'South Kensington Comedy Club',
#   "Music at Mama's with DJ Jasmine",
#   'Juli Szatmari: Singer Songwriter',
#   'ROOTS 2 @ Acklam Village',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   '',
#   "New Moon Sound Meditation & Women's Circle",
#   'CBWG 40th Anniversary Gala Celebration',
#   'Velocio Launch x Jack Ultracyclist Everesting Celebration',
#   'Spaces in the City',
#   'London soul train cruise autumn special ',
#   'New Beginnings London',
#   'London Boat Party with FREE After Party!',
#   'Clapham Pub Crawl // 4 Venues // Free Shots // Discounted Drinks + MORE!',
#   'Drake Boat Party with FREE After Party!',
#   'The Tempest',
#   'Shakespeare Comedy ',
#   'Vivaldi Four Seasons by Candlelight',
#   'Sing QUEEN vs ABBA Live',
#   'Camden Bar Crawl',
#   'Date in a Dash present Speed Dating @ Ten London (Ages 24-36)',
#   '',
#   'MASSAOKE: Sing QUEEN vs ABBA Live',
#   'The Ukulele Ska Collective free party !',
#   'tosca',
#   'Khaki Fever Live in London!',
#   'City Comedy Club: 8pm',
#   'Speed Dating in Shoreditch @ The Viaduct (Ages 27-39) ',
#   'The One Where BONY Visits London: Social mixer and networking',
#   'Singles Party @ The Riverside (Age Range: 40-60)',
#   'London Soul Train Cruise (Autumn Special) Jazz Funk Soul Disco Boat',
#   'Gilla Band',
#   'London Marathon 2022',
#   'PAVEMENT, Live in London',
#   'Clinton Baptiste: Clinton Vs Ramone',
#   'London',
#   'Girlz B Like: 7th anniversary!',
#   '',
#   'Swing at St. Mary’s',
#   'Coyote Ugly London // Saturdays',
#   'Confessions Of A Traitor / Seething Akira / Karybdis / Broken Calling - London',
#   "Fast Stream London Night Out '22",
#   'RollerDisco',
#   'Hashtag Saturdays Tiger Tiger Student Sessions',
#   'Saturday Stand Up Comedy Club',
#   '#Saturdays | The Lighthouse Bar Shoreditch Student Tickets',
#   'Ese & The Vooduu People live at The Night Owl London',
#   'London Luxury Hotel Bars October Social Mixer@ The Athenaeum,Mayfair.',
#   'Diwali - Festival of Lights Celebrations',
#   'The Golden Nibs 2022',
#   "Swing at St Mary's",
#   'small world link up',
#   'HOPE Live 2022',
#   '',
#   'llusions The Drag Queen Show London - Drag Queen Show - London, UK',
#   'Karaoke Club',
#   'Illusions The Drag Queen Show London - Drag Queen Show - London, England',
#   'JiveMeToTheMonn @TheUnionTheatre',
#   'Greek Dinner with Locals',
#   'DJs and Cocktails, Every Saturday',
#   'Rooftop DJ Sessions, Free Every Saturday Night w/ Charles Vaughn',
#   'Exclusive Property Exhibition - Showcasing ELIE SAAB Hyde Park London',
#   'Scrying',
#   'STANDUP COMEDY SPECIAL - British Indian Buddies',
#   'Time Freedom, Personal Freedom, FINANCIAL Freedom - UK',
#   'One Constitution Avenue - Pakistan Property Show London',
#   'BLM Fest presents: Black Lives Matter Festival #WeMove',
#   'Ghosts of London: Haunting Stories & Legends Outdoor Game',
#   'HOUSE  @ CAVARI',
#   '',
#   '*** Y2K HITS IOE ***',
#   "'Joy and Justice Peace and Poetry' : in the spirit of Pope St John Paul II",
#   'Awakening the new Consciousness',
#   'SILENT DISCO WALKING MUSICALS TOUR PARTY',
#   'Alexisonfire in London',
#   'NEW EP LAUNCH GIG PARTY',
#   'Underground Sound Presents - Amersham Arms',
#   'Social and business networking event at Home Grown Club',
#   'London Soul Train Cruise (Autumn special)',
#   'Asiana Diwali Boat Party - Sat 22nd October 2022',
#   'Peaky Blinders: The Redemption of Thomas Shelby',
#   'Ed Gamble - Electric',
#   'Vivaldi Four Seasons by Candlelight',
#   'Vivaldi Four Seasons by Candlelight',
#   '21Soho Presents...',
#   '',
#   'Drake Boat Party with FREE After Party!',
#   'Meet and meal at Pitanga',
#   'Joshua Jaswon Octet @ The Phoenix Theatre',
#   'Cocktails &VIP Soirée | Welcome Drink',
#   'Treasures of the Baroque',
#   'The Ukulele Ska Collective free party  at the Horatia',
#   'Quantum Leopard S08E01 w/ JOHN ROBERTSON',
#   'URUBU Dance Tribe presents: DRUM MANTRA - LIVE Ecstatic Dance + Cacao',
#   'Marc Maron',
#   'Ed Gamble - Electric',
#   'Wicked',
#   'REDUCER - RE-ANIMATED - THE GIG - THE FILM - ON TOUR AUTUMN 2022',
#   "That's Not My Name",
#   'REDUCER',
#   'Riverside  Singles Party  (Age Range: 40-60) **Free Drink Included**',
#   '',
#   'The Clapton Pot',
#   'ABBA Voyage',
#   "Creative Future Writers' Award Showcase",
#   'Tequila Sunrise - Reggaeton Party // Gabeto Camden',
#   'Enlightened Evenings',
#   'Northern Soul at the Rivoli Ballroom',
#   'The Great Gatsby - Immersive',
#   'Coyote Ugly London Camden // Saturday Night Large!',
#   'COGO & LWE present  Meduza (Live): Odizzea',
#   'Zoo Bar every Saturday in Leicester Square // 2 Floors of Music // Student Tickets',
#   'Tiger Tiger London // The Latin Explosion (Reggaeton Party)',
#   'Hashtag Saturdays Floripa Shoreditch Student Tickets',
#   'Our House Music!',
#   'Pocket Jam & Friends LIVE',
#   'Diwali - Festival of Lights Celebrations',
#   '',
#   'Good Vibes Only',
#   'OOZ x Bomb Factory',
#   'BLK Bottles London All BLK Rooftop Party',
#   'Muscle Men Male Strippers Revue & Male Strip Club Shows London England',
#   'Joe Rogan: The Sacred Clown Tour',
#   'Supa Dupa Fly x Back to the Old Skool',
#   'Saturday nights at The Swan',
#   'Clube Vicio - Kizomba Party & Dance Classes Every Saturday Night',
#   'Faded ',
#   'Southside Sessions',
#   'Alasdair Beckett-King',
#   'London Boat Party with FREE After Party!',
#   'Southside Sessions with EL-B and Jason Kaye',
#   "Clemence Wine & Cocktail Bar Mayfair - Saturday 80's DJ night",
#   'Jungle Bar (Weekend Food, Music & Entertainment)',
#   '',
#   'Mambista - Michael “Bammi” Rose + DJ Gerry Lyseight',
#   'Carwash',
#   'The London Bluegrass Band',
#   'HANNAH HORTON QUINTET',
#   'Glen Adams',
#   'Soul On The Square - A Celebration!',
#   'Hedex UK & EU Tour - London',
#   'SWAY / Every Saturday / Covent Garden / Student Drinks Deals / Open till 3am!',
#   'Tiger Tiger London every Saturday // 6 Rooms // Student Drink Deals!',
#   "Sip 'N Stroke | NUDE | 9pm - 12am| + AFTERPARTY",
#   'KOKO: Omar S',
#   'Hashtag Saturdays Piccadilly Institute Student Sessions',
#   'Hashtag Saturdays Zoo Bar Student Sessions',
#   'Parable presents: Fideles Live',
#   'Up On The Roof x Tropical Disco Records with The Reflex',
#   '',
#   'SWAY / Every Saturday / Covent Garden / Student Drinks Deals / Open till 3am!',
#   'Tiger Tiger London every Saturday // 6 Rooms // Student Drink Deals!',
#   "Sip 'N Stroke | NUDE | 9pm - 12am| + AFTERPARTY",
#   'KOKO: Omar S',
#   'Hashtag Saturdays Piccadilly Institute Student Sessions',
#   'Hashtag Saturdays Zoo Bar Student Sessions',
#   'NO GUIDANCE SATURDAYS',
#   'Parable presents: Fideles Live',
#   'Up On The Roof x Tropical Disco Records with The Reflex',
#   'Disco Sanctuary every Saturday ',
#   'Bashment Shutdown- Shoreditch Bashment Party',
#   'HipHop, Bashment & Afrobeats at The Lighthouse Bar',
#   'Amapiano Party - South London Takeover',
#   'Piano Nation - London’s Biggest Amapiano Party',
#   'A Disco in a Str!P Club',
#   '',
#   'Ghosts of London: Haunting Stories & Legends Outdoor Game',
#   'AMAPIANO SHUTDOWN - South London’s Biggest Party',
#   'Afrobeats vs Amapiano - South London’s Biggest Party',
#   'Afrobeats, Amapiano and Bashment at Lit Clapham',
#   'ONO LONDON - City Party',
#   'ONO LONDON - City Vibes',
#   'ONO LONDON - Afrobeats City Party',
#   'Suspiciously Elvis',
#   'Club de Fromage ',
#   'Not Another Indie Disco - Arctic Monkeys Special',
#   'Transcend & Dark Matter',
#   'Milonga Nacimiento - 1 Year Anniversary (Double Show with Special Guest: Hernan Gaston Lazart)',
#   'Interplanetary Criminal, Kikelomo, Bluetoof',
#   'The South London Soul Train with Eva Lazarus (Live) + More',
#   'Eva Lazarus (Live) + More',
#   '',
#   'ONO LONDON - City Vibes',
#   'ONO LONDON - Afrobeats City Party',
#   'Suspiciously Elvis',
#   'Club de Fromage ',
#   'Not Another Indie Disco - Arctic Monkeys Special',
#   'Transcend & Dark Matter',
#   'Milonga Nacimiento - 1 Year Anniversary (Double Show with Special Guest: Hernan Gaston Lazart)',
#   'Interplanetary Criminal, Kikelomo, Bluetoof',
#   'The South London Soul Train with Eva Lazarus (Live) + More',
#   'Eva Lazarus (Live) + More',
#   'Viva Reggaeton / House / Pop - Safari Edition',
#   'Parable presents: Fideles Live, Gheist,  Ivory',
#   'Piano Nation - London’s Biggest Amapiano Party',
#   'Amapiano Party - South London Takeover',
#   'Bashment Shutdown- Shoreditch Bashment Party',
#   '',
#   'LOVE & LIQUOR',
#   'BASS ROOTS - Dubstep Sub-Genre Clash',
#   'Egg LDN Pres: Jay Lumen, Kyle E & Uakoz',
#   'MUSHY PEAS / charity night',
#   'HARRY-OKE - The Harry Styles & 1D Mass Singalong Party  - London',
#   "Mega Spanish Party | London's Biggest Fiesta (Feat. DJ ALEX MARTINI)",
#   'Amapiano Vs Afrobeats - London’s Biggest Genre Clash Party',
#   'Piano Nation - London’s Biggest Amapiano Party',
#   "REGGAETON FEST @ STUDIO 338 - LONDON'S MEGA REGGAETON PARTY - 22/10/22",
#   'Viva Brazil',
#   'ONO LONDON - City Vibes',
#   'Grown & Sexy In Shoreditch',
#   'Love Afrobeats & Bashment Party',
#   'Afrobeats Saturdays',
#   'Hungover LDN - London’s Craziest Party Ever!',
#   '',
#   "Mega Spanish Party | London's Biggest Fiesta (Feat. DJ ALEX MARTINI)",
#   'Amapiano Vs Afrobeats - London’s Biggest Genre Clash Party',
#   'Piano Nation - London’s Biggest Amapiano Party',
#   "REGGAETON FEST @ STUDIO 338 - LONDON'S MEGA REGGAETON PARTY - 22/10/22",
#   'Viva Brazil',
#   'ONO LONDON - City Vibes',
#   'Grown & Sexy In Shoreditch',
#   'Love Afrobeats & Bashment Party',
#   'Afrobeats Saturdays',
#   'Hungover LDN - London’s Craziest Party Ever!',
#   'HipHop, Bashment & Afrobeats at The Lighthouse Bar',
#   'Elevate',
#   'Strictly VIBEZ',
#   'Desi In The City : Old Skool Special!',
#   'Transcend & Dark Matter',
#   '',
#   'Access Bars Class-Barras de Access',
#   "Merlin’s Magical London - Sea Life + Shrek's Adventure + London Dungeon + The Lastminute.com London Eye + Madame Tussauds",
#   'Madame Tussauds London - Standard Entry',
#   'Merlin’s Magical London: 3 Attractions In 1 – Sea Life + Madame Tussauds + The Lastminute.com London Eye',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Madame Tussauds',
#   'Sea Life London - Standard Entry',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + The Lastminute.com London Eye + Madame Tussauds",
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Sea Life',
#   'Merlin’s Magical London: 3 Attractions In 1 – Sea Life + Shrek’s Adventure! + Madame Tussauds',
#   'Merlin’s Magical London: 3 Attractions In 1 -  The London Dungeon + Sea Life + Madame Tussauds',
#   'Madame Tussauds London - Standard Admission + Marvel 4d',
#   'Merlin’s Magical London: 5 Attractions In 1 –  London Dungeon + The Lastminute.com London Eye + Shrek’s Adventure + Sea Life + Madame Tussauds',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + Sea Life + Madame Tussauds",
#   'Merlin’s Magical London - Sea Life + Shrek’s Adventure! + The Lastminute.com London Eye',
#   'Shrek’s Adventure! London – Daily Entry',
#   '',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure + The Lastminute.com London Eye + Sea Life",
#   'Executions',
#   'Monopoly Lifesized - Classic Board',
#   'The View From The Shard',
#   'London Parks Autumn 10K Series - Battersea Park',
#   'Stick Man',
#   'Battersea Park - London Parks Autumn 10K Series',
#   'Come join us this Sunday at the Covenant Nation, Tottenham Court Road, W1T',
#   'Monopoly Lifesized - City Board',
#   'Monopoly Lifesized - Luxury Board',
#   'The Lastminute.com London Eye River Cruise',
#   'Nelson Tour - Sunday 23 October, 10am-12pm',
#   'Hackney Clothes Swap - Sustainability Day',
#   'Black Power Women of Brixton Walk',
#   'Forest School in Tower Hamlets (4-7 age)',
#   '',
#   'DAMAC COMES TO LONDON! Dubai Investment Property Show',
#   'LGD school of dance grand opening',
#   'Leisure Ride to Windsor, Everyone is welcome',
#   'Dubai Luxury Property Symposium Manchester',
#   'Perennis Launch Event: Sustainability Workshops',
#   'Charity Dog Walk In Hampstead Heath',
#   'FREE Repair, Reuse and Upcycling Event: Hackney Sustainability Day!',
#   'Jeff Wayne’s The War Of The Worlds: The Immersive Experience',
#   'Stick Man - Live On Stage',
#   'How to boost self-confidence',
#   'Essential communication skills',
#   'Conquering everyday fears',
#   'SUNDAY SERVICE',
#   'How does your mind work?',
#   'Face-painting by Auroras Mirror',
#   '',
#   'Leisure Ride to Windsor, Everyone is welcome',
#   'Dubai Luxury Property Symposium Manchester',
#   'Perennis Launch Event: Sustainability Workshops',
#   'Camden Preloved Vintage Kilo',
#   'Charity Dog Walk In Hampstead Heath',
#   'FREE Repair, Reuse and Upcycling Event: Hackney Sustainability Day!',
#   'Jeff Wayne’s The War Of The Worlds: The Immersive Experience',
#   'Stick Man - Live On Stage',
#   'How to boost self-confidence',
#   'Essential communication skills',
#   'Conquering everyday fears',
#   'SUNDAY SERVICE',
#   'How does your mind work?',
#   'Face-painting by Auroras Mirror',
#   'Autumn wild food Forage and Feast in Mountsfield Park',
#   '',
#   'Yoga Teacher Emergency First Aid',
#   'Zin jam session London w/ Katerina',
#   'London Satsang Shakti Durga',
#   'Vegetarian Turkish cookery class with Meral | Station Style | LONDON',
#   "Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye+ Madame Tussauds + Shrek's Adventure",
#   'Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye + Madame Tussauds + Sealife London',
#   'Much Ado About Nothing',
#   'Sunday Jazz Lunch At Belgravia',
#   'Sunday Jazz Lunch',
#   'Big Fish Little Fish WOOD GREEN Halloween(ish) Family Rave 23 Oct 12-2pm',
#   'The Lion, The Witch And The Wardrobe',
#   'Harry Potter And The Cursed Child',
#   'Frozen The Musical',
#   'Cinema Comic Con: The Mighty World of Marvel, road to Black Panther 2 (Pt1)',
#   'Apple Day at Gillespie Park',
#   '',
#   'Yoga Teacher Emergency First Aid',
#   'Zin jam session London w/ Katerina',
#   'London Satsang Shakti Durga',
#   'Vegetarian Turkish cookery class with Meral | Station Style | LONDON',
#   "Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye+ Madame Tussauds + Shrek's Adventure",
#   'Merlin’s Magical London: 3 Attractions In 1 – The Lastminute.com London Eye + Madame Tussauds + Sealife London',
#   'Much Ado About Nothing',
#   'Sunday Jazz Lunch At Belgravia',
#   'Sunday Jazz Lunch',
#   'Big Fish Little Fish WOOD GREEN Halloween(ish) Family Rave 23 Oct 12-2pm',
#   'The Lion, The Witch And The Wardrobe',
#   'Harry Potter And The Cursed Child',
#   'Frozen The Musical',
#   'Cinema Comic Con: The Mighty World of Marvel, road to Black Panther 2 (Pt1)',
#   'Apple Day at Gillespie Park',
#   '',
#   'Free guided walk through Hackney green spaces',
#   "MusicOnWheels Workshops + UA Fundraiser - Queen's Park",
#   'LONDON - Afrobeats N Brunch: Sunday 23rd Oct UK Tour',
#   'Fun Mums Club Launch Brunch',
#   'LEAFF2022: ODEON WEST END | A CONFUCIAN CONFUSION | Screen 1',
#   'Tooting Lights Up - Diwali celebration in the heart of Tooting',
#   'SANPELLEGRINO PIAZZA BAR',
#   'Ukrainian Welcome Centre: Consultations with a Psychologist',
#   'Social event for Greek doctors - Hellenic Medical Society of UK',
#   'LONDON - Afrobeats N Brunch: Sunday 23rd Oct UK Tour',
#   'Love Shack Market',
#   'The Gunpowder Plot',
#   'Stick Man - Live On Stage',
#   'Heathers The Musical',
#   'Chelsea FC Fans Pre Match Boat Party',
#   '',
#   'SEASON 22 - MUAY THAI',
#   'Forest School in Tower Hamlets (7-12 years, drop off)',
#   "The Kids' Table at Davy's Wine Vaults, Greenwich",
#   'Fortnum & Mason’s Food Behind the Pages: Ruth Rogers & Sian Wyn Owen',
#   'Ukrainian Welcome Centre: Ceramics Class',
#   'The Deep Art Of Connection - Unlocking greater depths within - In Person',
#   'AND THE BEAT GOES OM-Tantric Trance Dance, Sound Journey, Ecstatic Dance',
#   '@2:50 - ten minutes of daily mindfulness EEST  (in BST)',
#   'Harry Potter and the Cursed Child - Parts 1 & 2 Sun 13:00 & 18:00',
#   'ABBA Voyage',
#   'Centenary Archons of the Ecumenical Patriarchate Luncheon',
#   'The Drifters Girl',
#   'A Feather on the Breath of God: Hildegard of Bingen',
#   'The Sunday Open Age Skate Session',
#   'Womens Wisdom day retreat',
#   '',
#   'Conquering everyday fears',
#   'How does your mind work?',
#   'Essential communication skills',
#   'Alpha Church Sunday Service',
#   'How to boost self-confidence',
#   'Peaky Blinders: The Rise',
#   "Vasily Petrenko's Mahler",
#   'Life Of Pi',
#   'Back To The Future - The Musical',
#   'The Play That Goes Wrong',
#   'A Sci-Fi Curriculum Reading Group: Glitch, Mutate, Dissolve to Water',
#   'CREATIVE ROOM  X SONS OF CRAFT',
#   'Witness For The Prosecution',
#   'Walking Tour - Alexandra Park and its heritage',
#   'Influences ',
#   '',
#   'llusions The Drag Queen Show London - Drag Queen Show - London, UK',
#   'Conquering everyday fears',
#   'How does your mind work?',
#   'Essential communication skills',
#   'Alpha Church Sunday Service',
#   'How to boost self-confidence',
#   'Peaky Blinders: The Rise',
#   "Vasily Petrenko's Mahler",
#   'Life Of Pi',
#   'Back To The Future - The Musical',
#   'The Play That Goes Wrong',
#   'A Sci-Fi Curriculum Reading Group: Glitch, Mutate, Dissolve to Water',
#   'CREATIVE ROOM  X SONS OF CRAFT',
#   'Witness For The Prosecution',
#   'Walking Tour - Alexandra Park and its heritage',
#   '',
#   'Peaky Blinders: The Redemption of Thomas Shelby',
#   'The Choir Of Man',
#   'Jordan Luke Gage [Matinee]',
#   'Wicked',
#   "MusicOnWheels Workshops + UA Fundraiser - Queen's Park",
#   'ONLINE: Meditation for Busy Parents. Easy & practical experiences.',
#   "ONLINE: Let's Meditate Camden- Free Guided Meditation",
#   'London Spiritual Meditation: Online Guided Session',
#   'ONLINE: Guided Kundalini Yoga Meditation. Free Course',
#   'ONLINE: Hackney Free Guided Meditation',
#   'ONLINE: London Stress Management Through Meditation',
#   'FunnyBoyz presents... Sunday Funday with drag queens inc. Cabaret & Bingo',
#   "Vasily Petrenko's Mahler",
#   'Big Fish Little Fish WOOD GREEN Halloween(ish) Family Rave 23 Oct 3-5pm',
#   'Six The Musical (vaudeville Theatre)',
#   '',
#   'Big Jam at The Amersham',
#   'Peaky Blinders: The Redemption of Thomas Shelby',
#   'The Choir Of Man',
#   'Jordan Luke Gage [Matinee]',
#   'Wicked',
#   "MusicOnWheels Workshops + UA Fundraiser - Queen's Park",
#   'ONLINE: Meditation for Busy Parents. Easy & practical experiences.',
#   "ONLINE: Let's Meditate Camden- Free Guided Meditation",
#   'London Spiritual Meditation: Online Guided Session',
#   'ONLINE: Guided Kundalini Yoga Meditation. Free Course',
#   'ONLINE: Hackney Free Guided Meditation',
#   'ONLINE: London Stress Management Through Meditation',
#   'FunnyBoyz presents... Sunday Funday with drag queens inc. Cabaret & Bingo',
#   "Vasily Petrenko's Mahler",
#   'Big Fish Little Fish WOOD GREEN Halloween(ish) Family Rave 23 Oct 3-5pm',
#   '',
#   'Poster Comedy Club - Free Standup Show in Stoke Newington',
#   'Channel One Sound System - Sunday Session',
#   'The Great Gatsby',
#   'Afternoon Tea and a Film',
#   'HOW TO INCREASE YOUR SELF-CONFIDENCE',
#   'What Being Confident Can do For You!',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   'The Great Gatsby',
#   'Circle of Listening',
#   'BBL Championship: London Lions v Manchester Giants',
#   'Greenwich Trio',
#   'RevPro Wrestling: Live In London 66 feat: Minoru Suzuki!',
#   'ABBA Voyage',
#   'James Bond Concert Spectacular',
#   'Channel One Sound System - Sunday Session',
#   '',
#   'SACRED AND PROFANE: ARRANGEMENTS FOR CELLO ENSEMBLE',
#   'Deptford Dub Club: Prince Fatty Special',
#   'Autumn Reset',
#   'The London routes of reggae',
#   'The Great Gatsby - Immersive',
#   "Pri's Art Salon: SCREAM",
#   'Short n Sweet Sundays - Autumn Bottomlesss Drunch',
#   'CongeeCon 2022',
#   'South Kensington Comedy Club',
#   'Yvonne Brewster OBE and Lynette Linton: A Theatre Director’s Life',
#   'Dead Girls Academy at The Underworld Camden - London',
#   'GURLS LINK UP',
#   'The Showcase of Dreams 2022',
#   'Albert Lee-Legendary Guitarist',
#   'Apples and Snakes presents Jawdance x Bloomsbury Festival',
#   '',
#   'James Bond Concert Spectacular',
#   'Channel One Sound System - Sunday Session',
#   'SACRED AND PROFANE: ARRANGEMENTS FOR CELLO ENSEMBLE',
#   'Deptford Dub Club: Prince Fatty Special',
#   'Autumn Reset',
#   'The London routes of reggae',
#   'The Great Gatsby - Immersive',
#   "Pri's Art Salon: SCREAM",
#   'Short n Sweet Sundays - Autumn Bottomlesss Drunch',
#   'CongeeCon 2022',
#   'South Kensington Comedy Club',
#   'Yvonne Brewster OBE and Lynette Linton: A Theatre Director’s Life',
#   'Dead Girls Academy at The Underworld Camden - London',
#   'GURLS LINK UP',
#   'The Showcase of Dreams 2022',
#   '',
#   'Albert Lee-Legendary Guitarist',
#   'Apples and Snakes presents Jawdance x Bloomsbury Festival',
#   'SEASON 22 - BOXING',
#   '2 Da Empire - ATJAZZ',
#   'Somali Week Festival: Books Day',
#   'Online Muslim Singles Event 25 -40 UK',
#   'NFL Season Kickoff Screening @ Old Street Brewery',
#   'Drag race uk screening with drag act host',
#   'An Evening of Inspiration & Unity, London',
#   'Black History Month: Shorts Film Screening with Corine Dhondee',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   'Reveur Presents - Shoot Your Shot',
#   'Pescatarian Nigerian Cookery Class with Stella | Station Style | LONDON',
#   'Jordan Luke Gage',
#   'Kino Short Film Open Mic',
#   '',
#   'Classical Palettes',
#   'RWR: bloody/bath / DEAFDEAFDEAF + more tba',
#   'Wrest + Support - London',
#   'Coracle',
#   'Seven Sisters / Hitten (SPA) / Parish - London',
#   'SEFO',
#   'RollOut',
#   'HALFNUMB LIVE',
#   '"This is Halloween" THE SHOW',
#   'Cloud Vision Events',
#   'RRFM Private Lunch Invite',
#   'Jack the Ripper Tours',
#   '[AUTOWEBINAR] AI & Gamification: The Good, The Bad, The Ugly',
#   "Tee's FAB FRIDAYS",
#   'Tom Lucy: Melt',
#   '',
#   'Stand Up Comedy in Spansish',
#   'Ghosts of London: Haunting Stories & Legends Outdoor Game',
#   'LONDON LAUNCH',
#   'SILENT DISCO WALKING MUSICALS TOUR PARTY',
#   'Latinos In London',
#   'Black Muslim Singles Event ❤️',
#   'Hope and Anchor 23rd October',
#   'Sacred Sound Journey',
#   'Jerry Paper',
#   'Marc Maron',
#   'Black Lesbians Speed Dating (Ages 24-35)',
#   "Luna's Sunday Jam",
#   'William The Conqueror + Later Youth live at The Lexington, London',
#   'Hashtag Sundays Floripa Shoreditch Student Tickets',
#   'Wrest - Notting Hill Arts Club | London',
#   '',
#   'Tears|OV + Rob Lye + Tom White',
#   'Ghosts of London: Haunting Stories & Legends Outdoor Game',
#   'Ghosts of London: Haunting Stories & Legends Outdoor Game',
#   'Orbit London Sunday night afterhours',
#   'Executions',
#   'Madame Tussauds London',
#   'Denver Broncos London Gameweek',
#   'Mindful Sound Flow - Open Class (Mondays 6.45am)',
#   'October Half Term Drama Club Age 7-15',
#   'October Half Term Photography Age 8-15',
#   'London Church Leaders Breakfast with Ecumenical Patriarch Bartholomew',
#   'LONDON OCTOBER HALF TERM CAMP 2022',
#   "Adaptogenic Monday's",
#   "Merlin’s Magical London - Madame Tussauds + The Lastminute.com London Eye + Shrek's Adventure",
#   'Madame Tussauds London - Standard Admission + Marvel 4d',
#   '',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Sea Life',
#   'Merlin’s Magical London: 5 Attractions In 1 –  London Dungeon + The Lastminute.com London Eye + Shrek’s Adventure + Sea Life + Madame Tussauds',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure + The Lastminute.com London Eye + Sea Life",
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + The Lastminute.com London Eye + Madame Tussauds",
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + Sea Life + Madame Tussauds",
#   'Shrek’s Adventure! London – Daily Entry',
#   'Executions',
#   'October half Term Cooking workshop',
#   'Halloween Photoshoot for Kids',
#   'The Lastminute.com London Eye River Cruise',
#   'HYPU October Half term Programme',
#   'Baking Made Easy',
#   'Kids En Cuisine - Halloween cooking camp - 24-28/10/22',
#   'Halloween cooking camp  24/10: Roasted butternut & chocolate mousse',
#   'October Half-Term: Tree Treasure Hunt Workshop for 2-6 year olds',
#   '',
#   'KIDS AUTUMN CAMP, 24 -28 OCTOBER 2022: Please see descriptions for payments',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Madame Tussauds',
#   'Merlin’s Magical London: 3 Attractions In 1 -  The London Dungeon + Sea Life + Madame Tussauds',
#   'Merlin’s Magical London: 3 Attractions In 1 – The London Dungeon + The Lastminute.com London Eye + Sea Life',
#   'Merlin’s Magical London: 5 Attractions In 1 –  London Dungeon + The Lastminute.com London Eye + Shrek’s Adventure + Sea Life + Madame Tussauds',
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure + The Lastminute.com London Eye + Sea Life",
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + The Lastminute.com London Eye + Madame Tussauds",
#   "Merlin’s Magical London: 3 Attractions In 1 – Shrek's Adventure! + Sea Life + Madame Tussauds",
#   'Shrek’s Adventure! London – Daily Entry',
#   'Executions',
#   'October half Term Cooking workshop',
#   'Halloween Photoshoot for Kids',
#   'The Lastminute.com London Eye River Cruise',
#   'HYPU October Half term Programme',
#   'Baking Made Easy',
#   '',
#   'Kids En Cuisine - Halloween cooking camp - 24-28/10/22',
#   'Halloween cooking camp  24/10: Roasted butternut & chocolate mousse',
#   'October Half-Term: Tree Treasure Hunt Workshop for 2-6 year olds',
#   'Elmwood  Tennis Camps - October- Week & Daily sessions',
#   'YEMAYA Holistic Music Movement & Art for Babies and Children',
#   'Plant Magic Emporium workshop: Sigils, Spells & Science',
#   'LIVE Catering Equipment Demonstrations',
#   'Brent Cross: Children’s Baking Classes & Adults Sparkling Cream Tea',
#   'YAS October Half Term Camp - WONDERLAND',
#   'YAS October Half Term - WONDERLAND -  Monday',
#   "'Look Good Feel Better' Hand and Nail  Workshop; for breast cancer care.",
#   'Hackney Fine Arts Holiday Classes Morning Sessions at Farmyard Studio',
#   'Hackney Fine Arts Holiday Classes Morning Sessions at Main Building Studio',
#   'Halloween workshop with the LEGO Group',
#   'City Safari - a Treasure Hunt for Families',
#   '',
#   'Wellness Workshop - Stress, Resilience and Rest',
#   'Exploring Digital Identity for Policy Makers',
#   'CultureTree celebrates Black History Month',
#   'What works in government: 10 years of using evidence to make better policy',
#   'Storytelling for Families: Gold Vault Break-In',
#   'DERIC CHNG ART DINING AND ART SHOW EXPERIENCE 2022',
#   'Vibes Groovers - Perform North End Road Festival',
#   'Ghostcloud by Michael Mann',
#   'PMC Presents Dolby Atmos Under The Microscope with Nick Rives',
#   'Japan House London Family Workshops',
#   'Singer System Ten - ICL’s Surprise Success Story',
#   'Hackney Fine Arts Holiday Classes Afternoon Sessions at Farmyard Studio',
#   'Hackney Fine Arts Holiday Afternoon classes with  SEND Main Building Studio',
#   "The Big Draw Workshop With John O'Leary @ Wood Street Library",
#   "Half Term Art Workshop with John O'Leary @Higham Hill Library",
#   '',
#   'Storytelling for Families: Gold Vault Break-In',
#   'Havana Nights',
#   'Reggaeton Mondays FREE entry b4 9pm',
#   'Dare to be Bold - Fashion Styling, Arts Workshop +  Photoshoot',
#   "China: Xi's Rule",
#   'Diwali Celebration Craft @North Chingford Library',
#   'Energy Healing in Covent Garden',
#   'Active Change Haringey Launch Event',
#   'THE FILM ATELIER ~ LEWISHAM/SE LONDON  GROUP  COGNITIVE ANALYTIC THERAPY',
#   'Romantic Notting Hill: Outdoor Escape Game for Couples - Love in London',
#   'Celebrating the Black Academic Pipeline  in FoNS: meet and greet w/ Q&A',
#   'Contemporary fusion',
#   'Wandsworth Lodge Installation Meeting ',
#   'Students, no more beans on toast!',
#   'CSA Lecture Series: Dr Mike Short, Chief Scientific Adviser at DIT',
#   '',
#   '“Black & Queer - we\'ve always been here"',
#   'WCN X WOCI with Symrath Patti',
#   'My Neighbour Totoro',
#   'Cave in plus stake',
#   'To K*ll A Mockingbird',
#   'Islington Radio Acoustic Showcase',
#   'WREN -  New Date',
#   "HYBRID IAS Book Launch 'Music and Digital Media: A Planetary Anthropology'",
#   ...],
#  'Mois': ['Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   '',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
#   'Oct',
# ...
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '22',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '23',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   '24',
#   ...],
#  'Ville': ['London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   'London',
#   ...]}
